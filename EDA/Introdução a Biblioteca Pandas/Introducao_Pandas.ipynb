# %% [markdown]
# <h1 style="color: #3e7bac; font-size: 45px;">Transformação de Dados com Pandas <br> 🐼🐍 </h1>
# <h3 style="color: #3e7bac;"> O Objetivo desse documento e trazer uma breve introdução a biblioteca pandas e como realizar os primeiros plots utilizando pandas e algumas outras bibliotecas. </h3>
# <h3 style="color: #3e7bac;"> Fica aqui um agradecimento em especial a comunidade Py013 em abrir esse espaço para trocarmos conhecimentos. </h3>
#
# <h2 style="color: #000;"> <br> Bora colocar a mão na massa!!! : )</h2>
#
# <img src="./images/py013_logo.jpeg" style="float:right; height:65px;"/>

# %% [markdown]
# ## Importa as Bibliotecas Necessárias
# ***

# %%
import pandas  as pd
import seaborn as sns
import numpy   as np
import matplotlib.pyplot as plt

# %% [markdown]
# ## Importa Nossa Base de Dados
# ***

# %%
df = pd.read_csv('NY_Bike_.csv', sep=';')

# %% [markdown]
# ### Descobrindo Nossa Base
# #### Estaremos explorando a base de locação de bicicletas do CityBank na cidade de Nova York, no ano de 2016.
# ### [Link da Base de Dados no Kaggle](https://www.kaggle.com/akkithetechie/new-york-city-bike-share-dataset) <br>
# Abaixo temos uma descrição de nossa base de dados.

# %% [markdown]
# | Nome da Coluna 	| Descrição                               	| Valores                                                                             	|
# |----------------	|-----------------------------------------	|-------------------------------------------------------------------------------------	|
# | start          	| Data de Ínicio da Corrida               	| Datetime                                                                            	|
# | end            	| Data de Termino da Corrida              	| Datetime                                                                            	|
# | ss_id          	| Id da Estação de Ínicio (Start Station) 	| **ss_** = Start Station                                                                 	|
# | ss_name        	| Nome da Estação de Ínicio               	|                                                                                     	|
# | ss_lat         	| Latitude da Estação de Ínicio           	|                                                                                     	|
# | ss_lon         	| Longitude da Estação de Ínicio          	|                                                                                     	|
# | es_id          	| Id da Estação de Termino (End Station)  	| **es_** = End Station                                                                   	|
# | es_name        	| Nome da Estação de Termino              	|                                                                                     	|
# | es_lat         	| Latitude da Estação de Termino          	|                                                                                     	|
# | es_lon         	| Longitude da Estação de Termino         	|                                                                                     	|
# | bike_id        	| Id da Bicicleta                         	| Identificador da bicicleta                                                          	|
# | user_type      	| Tipo de Usuário                         	| (**Customer** = Passe de 24 horas; **User** = Passe de 3 dias;  **Subscriber** = Membro Anual) 	|
# | birth_year     	| Ano de Nascimento do Usuário            	| Ano                                                                                 	|
# | gender         	| Gênero                                  	| (**0** = Desconhecido; **1** = Masculino; **2** = Feminino)                                  	|

# %%
df.head()
# Out:
#                  start                  end  ss_id        ss_name     ss_lat  \
# 0  2016-01-01 00:02:52  2016-01-01 00:08:54   3186  Grove St PATH  40.719586
# 1  2016-01-01 00:18:22  2016-01-01 00:21:42   3186  Grove St PATH  40.719586
# 2  2016-01-01 00:18:25  2016-01-01 00:21:47   3186  Grove St PATH  40.719586
# 3  2016-01-01 00:23:13  2016-01-01 00:27:21   3209   Brunswick St  40.724176
# 4  2016-01-01 01:03:20  2016-01-01 01:18:24   3195        Sip Ave  40.730743
#
#       ss_lon  es_id         es_name     es_lat     es_lon  bike_id  \
# 0 -74.043117   3209    Brunswick St  40.724176 -74.050656    24647
# 1 -74.043117   3213  Van Vorst Park  40.718489 -74.047727    24605
# 2 -74.043117   3213  Van Vorst Park  40.718489 -74.047727    24689
# 3 -74.050656   3203   Hamilton Park  40.727596 -74.044247    24693
# 4 -74.063784   3210  Pershing Field  40.742677 -74.051789    24573
#
#    usert_type  birth_year  gender
# 0  Subscriber      1964.0       2
# 1  Subscriber      1962.0       1
# 2  Subscriber      1962.0       2
# 3  Subscriber      1984.0       1
# 4    Customer      1984.0       0

# %%
df.T
# Out:
#                          0                    1                    2       \
# start       2016-01-01 00:02:52  2016-01-01 00:18:22  2016-01-01 00:18:25
# end         2016-01-01 00:08:54  2016-01-01 00:21:42  2016-01-01 00:21:47
# ss_id                      3186                 3186                 3186
# ss_name           Grove St PATH        Grove St PATH        Grove St PATH
# ss_lat                  40.7196              40.7196              40.7196
# ss_lon                 -74.0431             -74.0431             -74.0431
# es_id                      3209                 3213                 3213
# es_name            Brunswick St       Van Vorst Park       Van Vorst Park
# es_lat                  40.7242              40.7185              40.7185
# es_lon                 -74.0507             -74.0477             -74.0477
# bike_id                   24647                24605                24689
# usert_type           Subscriber           Subscriber           Subscriber
# birth_year                 1964                 1962                 1962
# gender                        2                    1                    2
#
#                          3                    4                    5       \
# start       2016-01-01 00:23:13  2016-01-01 01:03:20  2016-01-01 01:03:28
# end         2016-01-01 00:27:21  2016-01-01 01:18:24  2016-01-01 01:18:11
# ss_id                      3209                 3195                 3195
# ss_name            Brunswick St              Sip Ave              Sip Ave
# ss_lat                  40.7242              40.7307              40.7307
# ss_lon                 -74.0507             -74.0638             -74.0638
# es_id                      3203                 3210                 3210
# es_name           Hamilton Park       Pershing Field       Pershing Field
# es_lat                  40.7276              40.7427              40.7427
# es_lon                 -74.0442             -74.0518             -74.0518
# bike_id                   24693                24573                24442
# usert_type           Subscriber             Customer             Customer
# birth_year                 1984                 1984                 1984
# gender                        1                    0                    0
#
#                          6                    7                    8       \
# start       2016-01-01 01:07:45  2016-01-01 01:18:51  2016-01-01 01:23:44
# end         2016-01-01 01:15:11  2016-01-01 01:22:03  2016-01-01 01:30:34
# ss_id                      3186                 3211                 3187
# ss_name           Grove St PATH           Newark Ave            Warren St
# ss_lat                  40.7196              40.7215              40.7211
# ss_lon                 -74.0431             -74.0463             -74.0381
# es_id                      3203                 3203                 3214
# es_name           Hamilton Park        Hamilton Park     Essex Light Rail
# es_lat                  40.7276              40.7276              40.7128
# es_lon                 -74.0442             -74.0442             -74.0365
# bike_id                   24510                24625                24429
# usert_type           Subscriber           Subscriber           Subscriber
# birth_year                 1988                 1980                 1990
# gender                        2                    1                    1
#
#                          9       ...               495158  \
# start       2016-01-01 01:25:12  ...  2016-12-31 21:48:33
# end         2016-01-01 01:29:57  ...  2016-12-31 21:52:09
# ss_id                      3187  ...                 3205
# ss_name               Warren St  ...    JC Medical Center
# ss_lat                  40.7211  ...              40.7165
# ss_lon                 -74.0381  ...             -74.0496
# es_id                      3214  ...                 3186
# es_name        Essex Light Rail  ...        Grove St PATH
# es_lat                  40.7128  ...              40.7196
# es_lon                 -74.0365  ...             -74.0431
# bike_id                   24407  ...                24590
# usert_type           Subscriber  ...           Subscriber
# birth_year                 1988  ...                 1985
# gender                        2  ...                    1
#
#                          495159               495160               495161  \
# start       2016-12-31 21:52:13  2016-12-31 22:04:14  2016-12-31 23:02:01
# end         2016-12-31 22:01:32  2016-12-31 22:12:07  2016-12-31 23:06:03
# ss_id                      3193                 3186                 3214
# ss_name            Lincoln Park        Grove St PATH     Essex Light Rail
# ss_lat                  40.7246              40.7196              40.7128
# ss_lon                 -74.0784             -74.0431             -74.0365
# es_id                      3195                 3268                 3276
# es_name                 Sip Ave       Lafayette Park     Marin Light Rail
# es_lat                  40.7307              40.7135              40.7146
# es_lon                 -74.0638             -74.0629             -74.0428
# bike_id                   26431                24525                26232
# usert_type           Subscriber           Subscriber           Subscriber
# birth_year                 1986                 1991                 1958
# gender                        1                    1                    1
#
#                            495162               495163               495164  \
# start         2016-12-31 23:10:00  2016-12-31 23:10:16  2016-12-31 23:29:39
# end           2016-12-31 23:16:17  2016-12-31 23:19:33  2017-01-01 00:15:29
# ss_id                        3206                 3214                 3183
# ss_name                   Hilltop     Essex Light Rail       Exchange Place
# ss_lat                    40.7312              40.7128              40.7162
# ss_lon                   -74.0576             -74.0365             -74.0335
# es_id                        3225                 3203                 3183
# es_name     Baldwin at Montgomery        Hamilton Park       Exchange Place
# es_lat                    40.7237              40.7276              40.7162
# es_lon                   -74.0642             -74.0442             -74.0335
# bike_id                     24421                24465                24389
# usert_type             Subscriber           Subscriber             Customer
# birth_year                   1984                 1981                 1984
# gender                          1                    2                    0
#
#                          495165               495166               495167
# start       2016-12-31 23:44:37  2016-12-31 23:44:50  2016-12-31 23:44:50
# end         2016-12-31 23:47:31  2017-01-01 00:25:14  2017-01-01 00:25:10
# ss_id                      3186                 3214                 3214
# ss_name           Grove St PATH     Essex Light Rail     Essex Light Rail
# ss_lat                  40.7196              40.7128              40.7128
# ss_lon                 -74.0431             -74.0365             -74.0365
# es_id                      3270                 3214                 3214
# es_name         Jersey & 6th St     Essex Light Rail     Essex Light Rail
# es_lat                  40.7253              40.7128              40.7128
# es_lon                 -74.0456             -74.0365             -74.0365
# bike_id                   24641                26219                24471
# usert_type           Subscriber           Subscriber           Subscriber
# birth_year                 1978                 1960                 1956
# gender                        1                    2                    1
#
# [14 rows x 495168 columns]

# %%
#Dimensões da Base
df.shape
# Out:
# (495168, 14)

# %%
print("Quantas linhas o DataFrame contém?\nR: {0} Linhas ".format(df.shape[0]))
print("\nQuantas colunas o DataFrame contém?\nR: {0} Linhas ".format(df.shape[1]))
# Out:
# Quantas linhas o DataFrame contém?
# R: 495168 Linhas
#
# Quantas colunas o DataFrame contém?
# R: 14 Linhas

# %%
#Informações sobre nosso DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495168 entries, 0 to 495167
# Data columns (total 14 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   start       495168 non-null  object
#  1   end         495168 non-null  object
#  2   ss_id       495168 non-null  int64
#  3   ss_name     495168 non-null  object
#  4   ss_lat      495168 non-null  float64
#  5   ss_lon      495168 non-null  float64
#  6   es_id       495168 non-null  int64
#  7   es_name     495168 non-null  object
#  8   es_lat      495168 non-null  float64
#  9   es_lon      495168 non-null  float64
#  10  bike_id     495168 non-null  int64
#  11  usert_type  495168 non-null  object
#  12  birth_year  495168 non-null  float64
#  13  gender      495168 non-null  int64
# dtypes: float64(5), int64(4), object(5)
# memory usage: 52.9+ MB

# %%
df['start'] = df['start'].astype('datetime64[ns]') 
df['end']   = df['end'].astype('datetime64[ns]') 
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 495168 entries, 0 to 495167
# Data columns (total 14 columns):
#  #   Column      Non-Null Count   Dtype
# ---  ------      --------------   -----
#  0   start       495168 non-null  datetime64[ns]
#  1   end         495168 non-null  datetime64[ns]
#  2   ss_id       495168 non-null  int64
#  3   ss_name     495168 non-null  object
#  4   ss_lat      495168 non-null  float64
#  5   ss_lon      495168 non-null  float64
#  6   es_id       495168 non-null  int64
#  7   es_name     495168 non-null  object
#  8   es_lat      495168 non-null  float64
#  9   es_lon      495168 non-null  float64
#  10  bike_id     495168 non-null  int64
#  11  usert_type  495168 non-null  object
#  12  birth_year  495168 non-null  float64
#  13  gender      495168 non-null  int64
# dtypes: datetime64[ns](2), float64(5), int64(4), object(3)
# memory usage: 52.9+ MB

# %%
#Estatisticas Descritivas
df.describe().round(0)
# Out:
#           ss_id    ss_lat    ss_lon     es_id    es_lat    es_lon   bike_id  \
# count  495168.0  495168.0  495168.0  495168.0  495168.0  495168.0  495168.0
# mean     3207.0      41.0     -74.0    3204.0      41.0     -74.0   24935.0
# std        27.0       0.0       0.0      62.0       0.0       0.0     748.0
# min      3183.0      41.0     -74.0     147.0      41.0     -74.0   14552.0
# 25%      3186.0      41.0     -74.0    3186.0      41.0     -74.0   24491.0
# 50%      3201.0      41.0     -74.0    3199.0      41.0     -74.0   24609.0
# 75%      3211.0      41.0     -74.0    3211.0      41.0     -74.0   24719.0
# max      3426.0      41.0     -74.0    3426.0      41.0     -74.0   27274.0
#
#        birth_year    gender
# count    495168.0  495168.0
# mean       1980.0       1.0
# std           9.0       1.0
# min        1900.0       0.0
# 25%        1975.0       1.0
# 50%        1982.0       1.0
# 75%        1986.0       1.0
# max        2000.0       2.0

# %%
#Matriz de Correlação
df.corr()
# Out:
#                ss_id    ss_lat    ss_lon     es_id    es_lat    es_lon  \
# ss_id       1.000000 -0.008811 -0.052622 -0.026318 -0.063455  0.110310
# ss_lat     -0.008811  1.000000 -0.248797 -0.019364  0.464309 -0.253089
# ss_lon     -0.052622 -0.248797  1.000000  0.029940 -0.245535  0.533838
# es_id      -0.026318 -0.019364  0.029940  1.000000 -0.010826 -0.100340
# es_lat     -0.063455  0.464309 -0.245535 -0.010826  1.000000 -0.241351
# es_lon      0.110310 -0.253089  0.533838 -0.100340 -0.241351  1.000000
# bike_id     0.122679 -0.027814  0.010049  0.049260 -0.024607  0.012199
# birth_year -0.003272  0.009970  0.001208 -0.000414  0.003935 -0.001986
# gender      0.034118  0.020263 -0.013647  0.017464  0.008957 -0.008779
#
#              bike_id  birth_year    gender
# ss_id       0.122679   -0.003272  0.034118
# ss_lat     -0.027814    0.009970  0.020263
# ss_lon      0.010049    0.001208 -0.013647
# es_id       0.049260   -0.000414  0.017464
# es_lat     -0.024607    0.003935  0.008957
# es_lon      0.012199   -0.001986 -0.008779
# bike_id     1.000000    0.011390  0.004252
# birth_year  0.011390    1.000000 -0.024325
# gender      0.004252   -0.024325  1.000000

# %% [markdown]
# ## Como adicionar uma coluna calculada?
# ***

# %%
df['id_ride'] = df.index + 1

# %%
df['diff_min'] = ((df['end'] - df['start']).dt.total_seconds() / 60).round(2)

# %%
df['dt_start'] = df['start'].dt.strftime('%Y-%m-%d')

# %%
df['month_st_nm'] = df['start'].dt.month

# %%
df['day_week']   = df['start'].dt.dayofweek
df['hour_start'] = df['start'].dt.hour

df['Age'] = np.where((2016 - df['birth_year']) <= 19, 'Jovem',
                     np.where((2016 - df['birth_year']) <= 59, 'Adulto', 'Idoso'))

# %% [markdown]
# ## Como Excluir uma Coluna?
# ***

# %%
del df['ss_id']
del df['es_id']

# %% [markdown]
# ## Travar um Range do Data Frame
#
# #### [Documentação da função loc](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.loc.html)
# ***

# %%
dfPivot = pd.DataFrame(df.loc[:,['day_week', 'hour_start', 'diff_min']])
dfPivot.head()
# Out:
#    day_week  hour_start  diff_min
# 0         4           0      6.03
# 1         4           0      3.33
# 2         4           0      3.37
# 3         4           0      4.13
# 4         4           1     15.07

# %% [markdown]
# ## "Pivotar"  e/ou Agrupar o DataFrame
#
# #### [Documentação da função pivot_table](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.pivot_table.html)
# #### [Documentação da função groupby](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.groupby.html)
# ***

# %%
pd.pivot_table(dfPivot
               , index   = "day_week"
               , columns = "hour_start"
               , values  = "diff_min"
               , aggfunc = "mean"
              )
# Out:
# hour_start         0          1          2          3          4           5   \
# day_week
# 0           12.083498  10.270000  52.232396  13.634590   6.199241    7.877345
# 1           20.262157  10.875657  26.652791  12.219808   8.297126    7.651812
# 2           12.010956  12.726239  11.331667   9.873158  10.518485    8.080578
# 3           15.540443  14.626583  17.046186  11.755556  12.321974    7.309062
# 4            9.925714  11.479072  10.707549  24.292817  24.840947    7.941720
# 5           16.777588  12.382540  16.270532  11.519333  23.657188  277.122041
# 6           16.902070  35.886687  11.655714  23.890588   7.602593    7.533178
#
# hour_start         6          7          8          9   ...         14  \
# day_week                                                ...
# 0            6.557835   7.439945   7.729557   8.522987  ...  16.463471
# 1            8.596586  92.423150   8.731016   9.170357  ...  19.118918
# 2            6.692361   7.034352   7.533641   8.111971  ...  14.580136
# 3            6.940088   7.654363   8.735653  21.766895  ...  12.604650
# 4            6.964624  18.766412  14.539828   8.699769  ...  13.628516
# 5           16.356785  10.571906  10.738055  13.219030  ...  20.519130
# 6           10.829686  19.248766  13.057690  16.907297  ...  20.402025
#
# hour_start         15         16         17         18         19         20  \
# day_week
# 0           15.090794  13.544728  10.891057  12.229027  11.842616   9.787547
# 1           12.013895  11.070793  10.031261  10.202245  10.764184  11.151261
# 2           14.785893  10.201217  31.343446  11.326756   9.689662  10.259411
# 3           12.843603  11.427256   9.898902  10.639020  10.450097  10.105516
# 4           13.529428  29.021355  10.870070  11.194284   9.729892  11.570759
# 5           26.765987  24.081172  18.400872  18.576793  13.981853  16.638865
# 6           23.195783  32.639113  18.603066  18.033046  15.545610  12.190103
#
# hour_start         21         22         23
# day_week
# 0           15.448329   8.901567  40.183978
# 1           10.317866   9.194268  17.986056
# 2           12.058198  13.425961  12.807607
# 3           10.752855  10.079508   8.368665
# 4           11.854732  12.912679  48.238509
# 5           10.196685  35.617497  12.587343
# 6           19.772908  11.176690  17.305787
#
# [7 rows x 24 columns]

# %%
pd.pivot_table(df
               , index   = "Age"
               , columns = "usert_type"
               , values  = "diff_min"
               , aggfunc = [np.mean, np.count_nonzero]
              )
# Out:
#                  mean            count_nonzero
# usert_type   Customer Subscriber      Customer Subscriber
# Age
# Adulto      50.422881  12.431072       31042.0   448982.0
# Idoso             NaN  10.619334           NaN    13984.0
# Jovem             NaN  15.513017           NaN     1160.0

# %%
pd.pivot_table(df, index = "Age"
               , columns = "usert_type"
               , aggfunc = {'diff_min' : np.mean
                          , 'start' : np.count_nonzero}
              )
# Out:
#              diff_min               start
# usert_type   Customer Subscriber Customer Subscriber
# Age
# Adulto      50.422881  12.431072  31042.0   448982.0
# Idoso             NaN  10.619334      NaN    13984.0
# Jovem             NaN  15.513017      NaN     1160.0

# %%
df.groupby(['month_st_nm'
            , 'Age'
           ]
          ).agg({'diff_min':np.mean
                 , 'id_ride':np.count_nonzero}
               ).reset_index()
# Out:
#     month_st_nm     Age   diff_min  id_ride
# 0             1  Adulto  14.783699    14410
# 1             1   Idoso   9.793755      538
# 2             1   Jovem  23.058000       10
# 3             2  Adulto  24.285115    15902
# 4             2   Idoso   9.191849      584
# 5             2   Jovem  15.910000       14
# 6             3  Adulto  34.456598    26154
# 7             3   Idoso   9.488523      826
# 8             3   Jovem  20.382381       42
# 9             4  Adulto  15.368380    31696
# 10            4   Idoso   9.173069      958
# 11            4   Jovem  15.296000       30
# 12            5  Adulto  13.683072    37594
# 13            5   Idoso  12.358641     1266
# 14            5   Jovem  14.402931      116
# 15            6  Adulto  14.254750    46290
# 16            6   Idoso  13.672571     1400
# 17            6   Jovem  15.097843      204
# 18            7  Adulto  13.747045    47450
# 19            7   Idoso  10.737637     1244
# 20            7   Jovem  10.687753      178
# 21            8  Adulto  13.301744    66442
# 22            8   Idoso  11.942545     1682
# 23            8   Jovem  15.754023      174
# 24            9  Adulto  14.347901    65110
# 25            9   Idoso   9.491689     1634
# 26            9   Jovem  22.100000      106
# 27           10  Adulto  11.229496    57464
# 28           10   Idoso  10.648446     1622
# 29           10   Jovem  14.601618      136
# 30           11  Adulto  13.931018    42302
# 31           11   Idoso   8.567134     1270
# 32           11   Jovem  16.860652       92
# 33           12  Adulto   9.582564    29210
# 34           12   Idoso   9.733625      960
# 35           12   Jovem  16.429655       58

# %% [markdown]
# # Exploração de Dados
# ***

# %% [markdown]
# ### BoxPlot de uma Métrica
#
# #### [Link da documentação do BoxPlot](https://seaborn.pydata.org/generated/seaborn.boxplot.html)
# ---

# %%
ax = sns.boxplot(df['diff_min'])

# %% [markdown]
# ## Tratativa de Outliers
# #### Vamos fazer de forma bem rápida a remoção de outliers.
#
# #### [Recomendo a leitura desse post no Medium](https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba)
# ---

# %%
# Vou usar o IQR para tratar os Outliers
Q1  = df['diff_min'].quantile(0.25)
Q3  = df['diff_min'].quantile(0.75)
IQR = Q3 - Q1
print(IQR)

# CRIA UM NOVO DATA FRAME REMOVENDO OS OUTLIERS
mask  = df['diff_min'].between(Q1, Q3, inclusive=True)
dfOut = df.loc[mask]

ax    = sns.boxplot(dfOut['diff_min'])
# Out:
# 6.969999999999999

# %%
fig, (ax, ax2) = plt.subplots(ncols=2, figsize=(15,5))
ax = sns.boxplot(df['diff_min'], ax=ax)
ax.set_title('Antes')
ax = sns.boxplot(dfOut['diff_min'], ax=ax2)
ax.set_title('Depois')
ax

# %% [markdown]
# ## Qual é a quantidade de corridas que temos mensalmente?
#
# #### [Link da documentação do gráfico de barras](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.bar.html)
# ---

# %%
ax = df.groupby(['month_st_nm']).start.count().reset_index().plot.bar(x='month_st_nm', y='start', figsize=(15,5))
ax.set_xlabel('Mês')
ax.set_ylabel('Qtd de Corridas')
ax.set_title('Qtd de Corridas Mês a Mês')
ax.legend(['Qtd'])
for p in ax.patches:
    ax.annotate(str(p.get_height()), (p.get_x() * 1.005, p.get_height() * 1.005))
ax

# %% [markdown]
# ## Como está a distribuição de corridas por dia de semana?
#
# Iremos usar a função dayofweek, ela retorna um número inteiro sendo (0 = Segunda-Feira e 6 = Domingo). <br>
# [Link da Documentação da Função](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.dayofweek.html)
#
# ---

# %%
ax = df.groupby(df['start'].dt.dayofweek).start.count().plot.line(x='start', y='start', figsize=(15,5))

# %% [markdown]
# ## Qual é o horário de maior pico x dia da semana?
#
# #### [Link da documentação do heatmap](https://seaborn.pydata.org/generated/seaborn.heatmap.html)
# ---

# %%
dfHM = pd.pivot_table(df, values="start",index=["hour_start"], columns=["day_week"], aggfunc=np.count_nonzero)
ax = sns.heatmap(dfHM, annot=True, fmt="d", cmap="Blues")
ax.figure.set_size_inches(16,8)

# %% [markdown]
# ## Quais são 10 as estações com mais starts?
#
# #### [Link da documentação da função nlargest](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.nlargest.html)
# ---

# %%
dfStation = pd.DataFrame(df.groupby('ss_name').start.count().reset_index())
ax = dfStation.nlargest(10, 'start').plot.bar(x='ss_name', y='start', figsize=(15,5))

# %% [markdown]
# ## Qual a % de Corridas que cada tipo de cliente representa?
#
# #### [Link da documentação do gráfico de torta](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.plot.pie.html)
# ---

# %%
explode = (0.1, 0)
ax = df.groupby(['usert_type']).id_ride.count().plot.pie( autopct='%1.1f%%',
        shadow=True, startangle=90, explode=explode, figsize=(12,6))

# %% [markdown]
# ## Qual a faixa de idade do público que consome nossas bikes?
#
# #### [Link da documentação do gráfico de distribuição](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)
# ---

# %%
dfMes = pd.DataFrame(df.groupby(['month_st_nm', 'hour_start', 'Age'])
                     .agg({'id_ride': np.count_nonzero}).reset_index()
                    )

# %%
sns.set(style="whitegrid")
ax = sns.scatterplot(x="month_st_nm", y="id_ride", hue="Age" ,data=dfMes)
ax.figure.set_size_inches(16,5)

# %%
ax = sns.scatterplot(x="month_st_nm", y="id_ride", hue="hour_start" ,data=dfMes[dfMes['Age'] == 'Jovem'])
ax.figure.set_size_inches(16,5)

# %% [markdown]
# # Plus - Mapa Com a Geolocalização
#
# ### Segue abaixo um exemplo de mapa com Geolocalização, para nós fornecer onde está localizada cada estação de bike.
#
# ### Utilizei a biblioteca Folium para plotar o mapa, [caso queira ler um pouco mais sobre a biblioteca segue o link](https://python-visualization.github.io/folium/)
# ---

# %%
# IMPORTA AS BIBLIOTECAS NECESSARIAS
import folium
from folium import plugins

# DEFINE UMA FOTO DO MAPA INICIAL, ESTOU SETANDO A CIDADE DE NOVA YORK
mapa = folium.Map(location=[40.7293305,-74.0424408],zoom_start=13)

# FAZ UM FOR NO DATA FRAME FILTRANDO AS LAT E LON E AGREGANDO QUAIS TIVERAM MAIS CORRIDAS.
for _, empresa in df.groupby(['ss_lat', 'ss_lon']).agg({'id_ride':np.count_nonzero}).reset_index().iterrows():
    
# CHAMA O METODO Marker, PARA FAZER UMA MARCA NO MAPA    
    folium.Marker(
        
# SETA A LOCALIZAÇÃO DA MARCA A SER CRIADA.
        
        location=[empresa['ss_lat'], empresa['ss_lon']],
        
# CRIA UM POPUP AO CLICAR NO PONTO, IRA EXEIBIR A QUANTIDADE DE CORRIDAS QUE TEVE.
            popup=empresa['id_ride'],
        
# ADICIONA OS PASSO AO MAPA
    ).add_to(mapa)

# EXIBE O MAPA
mapa
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="about:blank" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" data-html=... onload="this.contentDocument.open();this.contentDocument.write(atob(this.getAttribute('data-html')));this.contentDocument.close();" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
# EXPORTA O MAPA EM HTML
mapa.save('mapa_Station.html')
